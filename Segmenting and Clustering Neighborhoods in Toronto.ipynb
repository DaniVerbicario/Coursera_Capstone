# %% [markdown]
# # 1. Scraping Wikipedia page for retrieving data

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
url = 'https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'
page = requests.get(url)
soup = BeautifulSoup(page.content, 'html.parser') 
table = soup.find('table', class_= 'wikitable')
table_rows = table.find_all('tr')

# %%
l=[]
for tr in table_rows:
    td = tr.find_all("td")
    row = [tr.text.strip() for tr in td]
    if row !=[]:
        if row[1] != 'Not assigned':
            l.append(row)

# %%
df = pd.DataFrame(l,columns = ['PostalCode','Borough','Neighborhood'])

# %%
# Combining same postal codes neighborhoods and assigning the borough name to the non assigned neighborhoods.
i = 0
r = ["0"]
l=[]
for index, row in df.iterrows():
    if row[0] == r[i]:
        l.append(index)
    r += [row[0]]
    i = i + 1
    if row[2] == 'Not assigned':
        row[2] = row [1]

for i in l:
    df.Neighborhood[i-1] = df.Neighborhood[i-1] + ',' + df.Neighborhood[i]

df.drop(l)
# Out:
#     PostalCode           Borough  \
# 0          M3A        North York
# 1          M4A        North York
# 2          M5A  Downtown Toronto
# 4          M6A        North York
# 6          M7A      Queen's Park
# 7          M9A         Etobicoke
# 8          M1B       Scarborough
# 10         M3B        North York
# 11         M4B         East York
# 13         M5B  Downtown Toronto
# 15         M6B        North York
# 16         M9B         Etobicoke
# 21         M1C       Scarborough
# 24         M3C        North York
# 26         M4C         East York
# 27         M5C  Downtown Toronto
# 28         M6C              York
# 29         M9C         Etobicoke
# 33         M1E       Scarborough
# 36         M4E      East Toronto
# 37         M5E  Downtown Toronto
# 38         M6E              York
# 39         M1G       Scarborough
# 40         M4G         East York
# 41         M5G  Downtown Toronto
# 42         M6G  Downtown Toronto
# 43         M1H       Scarborough
# 44         M2H        North York
# 45         M3H        North York
# 48         M4H         East York
# ..         ...               ...
# 130        M4R   Central Toronto
# 131        M5R   Central Toronto
# 134        M6R      West Toronto
# 136        M7R       Mississauga
# 137        M9R         Etobicoke
# 141        M1S       Scarborough
# 142        M4S   Central Toronto
# 143        M5S  Downtown Toronto
# 145        M6S      West Toronto
# 147        M1T       Scarborough
# 150        M4T   Central Toronto
# 152        M5T  Downtown Toronto
# 155        M1V       Scarborough
# 159        M4V   Central Toronto
# 164        M5V  Downtown Toronto
# 171        M8V         Etobicoke
# 174        M9V         Etobicoke
# 182        M1W       Scarborough
# 183        M4W  Downtown Toronto
# 184        M5W  Downtown Toronto
# 185        M8W         Etobicoke
# 187        M9W         Etobicoke
# 188        M1X       Scarborough
# 189        M4X  Downtown Toronto
# 191        M5X  Downtown Toronto
# 193        M8X         Etobicoke
# 196        M4Y  Downtown Toronto
# 197        M7Y      East Toronto
# 198        M8Y         Etobicoke
# 206        M8Z         Etobicoke
#
#                                           Neighborhood
# 0                                            Parkwoods
# 1                                     Victoria Village
# 2                             Harbourfront,Regent Park
# 4                      Lawrence Heights,Lawrence Manor
# 6                                         Queen's Park
# 7                                     Islington Avenue
# 8                                        Rouge,Malvern
# 10                                     Don Mills North
# 11                      Woodbine Gardens,Parkview Hill
# 13                             Ryerson,Garden District
# 15                                           Glencairn
# 16                                Cloverdale,Islington
# 21                           Highland Creek,Rouge Hill
# 24                     Flemingdon Park,Don Mills South
# 26                                    Woodbine Heights
# 27                                      St. James Town
# 28                                  Humewood-Cedarvale
# 29                          Bloordale Gardens,Eringate
# 33                               Guildwood,Morningside
# 36                                         The Beaches
# 37                                         Berczy Park
# 38                                 Caledonia-Fairbanks
# 39                                              Woburn
# 40                                             Leaside
# 41                                  Central Bay Street
# 42                                            Christie
# 43                                           Cedarbrae
# 44                                   Hillcrest Village
# 45                      Bathurst Manor,Downsview North
# 48                                    Thorncliffe Park
# ..                                                 ...
# 130                                 North Toronto West
# 131                            The Annex,North Midtown
# 134                              Parkdale,Roncesvalles
# 136              Canada Post Gateway Processing Centre
# 137             Kingsview Village,Martin Grove Gardens
# 141                                          Agincourt
# 142                                         Davisville
# 143                      Harbord,University of Toronto
# 145                                  Runnymede,Swansea
# 147                            Clarks Corners,Sullivan
# 150                         Moore Park,Summerhill East
# 152                              Chinatown,Grange Park
# 155                    Agincourt North,L'Amoreaux East
# 159                           Deer Park,Forest Hill SE
# 164                             CN Tower,Bathurst Quay
# 171                     Humber Bay Shores,Mimico South
# 174                    Albion Gardens,Beaumond Heights
# 182                                    L'Amoreaux West
# 183                                           Rosedale
# 184                    Stn A PO Boxes 25 The Esplanade
# 185                              Alderwood,Long Branch
# 187                                          Northwest
# 188                                        Upper Rouge
# 189                         Cabbagetown,St. James Town
# 191              First Canadian Place,Underground city
# 193                       The Kingsway,Montgomery Road
# 196                               Church and Wellesley
# 197  Business Reply Mail Processing Centre 969 Eastern
# 198                        Humber Bay,King's Mill Park
# 206                 Kingsway Park South West,Mimico NW
#
# [103 rows x 3 columns]

# %%
df.shape
# Out:
# (211, 3)
